# %%
import pandas as pd
from pathlib import Path

matches = pd.read_csv("../data/processed/matches_clean.csv")

matches.describe()

# %%
matches.groupby("year")["total_goals"].sum().plot(title="Total goals per World Cup")
