# %%
import sys
from pathlib import Path
sys.path.append(str(Path("..").resolve()))

import pandas as pd
from src.features import teams_per_year
from src.analysis import worldcup_summary
from src.projection import projection_2026

matches = pd.read_csv("../data/processed/matches_clean.csv")

teams = teams_per_year(matches)
summary = worldcup_summary(matches, teams)

projection_2026(summary)
